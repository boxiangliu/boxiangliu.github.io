# %% [markdown]
# # Publications markdown generator for academicpages
#
# Takes a set of bibtex of publications and converts them for use with [academicpages.github.io](academicpages.github.io). This is an interactive Jupyter notebook ([see more info here](http://jupyter-notebook-beginner-guide.readthedocs.io/en/latest/what_is_jupyter.html)).
#
# The core python code is also in `pubsFromBibs.py`.
# Run either from the `markdown_generator` folder after replacing updating the publist dictionary with:
# * bib file names
# * specific venue keys based on your bib file preferences
# * any specific pre-text for specific files
# * Collection Name (future feature)
#
# TODO: Make this work with other databases of citations,
# TODO: Merge this with the existing TSV parsing solution

# %%
from pybtex.database.input import bibtex
import pybtex.database.input.bibtex 
from time import strptime
import string
import html
import os
import re

# %%
#todo: incorporate different collection types rather than a catch all publications, requires other changes to template
publist = {
    "proceeding": {
        "file" : "../files/publications.bib",
        "venuekey": "journal",
        "venue-pretext": "",
        "collection" : {"name":"publications",
                        "permalink":"/publication/"}
        
    }
}

# %%
html_escape_table = {
    "&": "&amp;",
    '"': "&quot;",
    "'": "&apos;"
    }

def html_escape(text):
    """Produce entities within text."""
    return "".join(html_escape_table.get(c,c) for c in text)

# %%
for pubsource in publist:
    parser = bibtex.Parser()
    bibdata = parser.parse_file(publist[pubsource]["file"])

    #loop through the individual references in a given bibtex file
    for bib_id in bibdata.entries.keys():
        #reset default date
        pub_year = "1900"
        pub_month = "01"
        pub_day = "01"
        
        b = bibdata.entries[bib_id].fields
        
        try:
            pub_year = f'{b["year"]}'

            #todo: this hack for month and day needs some cleanup
            if "month" in b.keys(): 
                if(len(b["month"])<3):
                    pub_month = "0"+b["month"]
                    pub_month = pub_month[-2:]
                elif(b["month"] not in range(12)):
                    tmnth = strptime(b["month"][:3],'%b').tm_mon   
                    pub_month = "{:02d}".format(tmnth) 
                else:
                    pub_month = str(b["month"])
            if "day" in b.keys(): 
                pub_day = str(b["day"])

                
            pub_date = pub_year+"-"+pub_month+"-"+pub_day
            
            #strip out {} as needed (some bibtex entries that maintain formatting)
            clean_title = b["title"].replace("{", "").replace("}","").replace("\\","").replace(" ","-")    

            url_slug = re.sub("\\[.*\\]|[^a-zA-Z0-9_-]", "", clean_title)
            url_slug = url_slug.replace("--","-")

            md_filename = (str(pub_date) + "-" + url_slug + ".md").replace("--","-")
            html_filename = (str(pub_date) + "-" + url_slug).replace("--","-")

            #Build Citation from text
            citation = ""

            #citation authors - todo - add highlighting for primary author?
            for author in bibdata.entries[bib_id].persons["author"]:
                if author.last_names[0] == "others":
                    citation = citation[:-2] + " et al."
                else:
                    citation = citation+" "+author.first_names[0]+" "+author.last_names[0]+", "
            print(citation)

            #citation title
            citation = citation + "\"" + html_escape(b["title"].replace("{", "").replace("}","").replace("\\","")) + ".\""

            #add venue logic depending on citation type
            venue = publist[pubsource]["venue-pretext"]+b[publist[pubsource]["venuekey"]].replace("{", "").replace("}","").replace("\\","")

            citation = citation + " " + html_escape(venue)
            citation = citation + ", " + pub_year + "."

            
            ## YAML variables
            md = "---\ntitle: \""   + html_escape(b["title"].replace("{", "").replace("}","").replace("\\","")) + '"\n'
            
            md += """collection: """ +  publist[pubsource]["collection"]["name"]

            md += """\npermalink: """ + publist[pubsource]["collection"]["permalink"]  + html_filename
            
            abstract = False
            if "abstract" in b.keys():
#                 if len(str(b["abstract"])) > 5:
#                     md += "\nexcerpt: '" + html_escape(b["abstract"]) + "'"
                    abstract = True

            md += "\ndate: " + str(pub_date) 

            md += "\nvenue: '" + html_escape(venue) + "'"
            
            url = False
            if "url" in b.keys():
                if len(str(b["url"])) > 5:
                    md += "\npaperurl: '" + b["url"] + "'"
                    url = True

            md += "\ncitation: '" + html_escape(citation) + "'"
            md += "\nexcerpt_separator: <!--more-->"
            md += "\n---"
            md += "\n<!--more-->"
            
            ## Markdown description for individual page
            if abstract:
                md += "\n" + html_escape(b["abstract"]) + "\n"

            if url:
                md += "\n[Access paper here](" + b["url"] + "){:target=\"_blank\"}\n" 
            else:
                md += "\nUse [Google Scholar](https://scholar.google.com/scholar?q="+html.escape(clean_title.replace("-","+"))+"){:target=\"_blank\"} for full citation"


            md_filename = os.path.basename(md_filename)

            with open("../_publications/" + md_filename, 'w') as f:
                f.write(md)
            print(f'SUCESSFULLY PARSED {bib_id}: \"', b["title"][:60],"..."*(len(b['title'])>60),"\"")
        # field may not exist for a reference
        except KeyError as e:
            print(f'WARNING Missing Expected Field {e} from entry {bib_id}: \"', b["title"][:30],"..."*(len(b['title'])>30),"\"")
            continue
# Out:
#  Brunilda Balliu,  Matthew Durrant,  Olivia Goede,  Nathan Abell,  Xin Li,  Boxiang Liu,  Michael Gloudemans,  Naomi Cook,  Kevin Smith,  David Knowles et al.
# SUCESSFULLY PARSED balliu2019genetic: " Genetic regulation of gene expression and splicing during a  ... "
#  Alvaro Barbeira,  Rodrigo Bonazzola,  Eric Gamazon,  Yanyu Liang,  YoSon Park,  Sarah Kim-Hellmuth,  Gao Wang,  Zhuoxun Jiang,  Dan Zhou,  Farhad Hormozdiari et al.
# SUCESSFULLY PARSED barbeira2019widespread: " Widespread dose-dependent effects of RNA expression and spli ... "
#  Colby Chiang,  Alexandra Scott,  Joe Davis,  Emily Tsang,  Xin Li,  Yungil Kim,  Tarik Hadzic,  Farhan Damani,  Liron Ganel,  Stephen Montgomery et al.
# SUCESSFULLY PARSED chiang2017impact: " The impact of structural variation on human gene expression  "
#  Laure Fr{\'e}sard,  Craig Smail,  Nicole Ferraro,  Nicole Teran,  Xin Li,  Kevin Smith,  Devon Bonner,  Kristin Kernohan,  Shruti Marwaha,  Zachary Zappala et al.
# SUCESSFULLY PARSED fresard2019identification: " Identification of rare-disease genes using blood transcripto ... "
#  GTEx Consortium et al.
# SUCESSFULLY PARSED gtex2017genetic: " Genetic effects on gene expression across human tissues  "
#  Yan Guo,  Min Lin,  Hua Li,  Hong Liang,  Bo Liu,  Zhong Liu,
# WARNING Missing Expected Field 'journal' from entry guo2012research: " The Research on the Improvemen ... "
#  Dharini Iyer,  Quanyi Zhao,  Robert Wirka,  Ameay Naravane,  Trieu Nguyen,  Boxiang Liu,  Manabu Nagao,  Paul Cheng,  Clint Miller,  Juyong Kim et al.
# SUCESSFULLY PARSED iyer2018coronary: " Coronary artery disease genes SMAD3 and TCF21 promote opposi ... "
#  Bina Kakusa,  Summer Han,  Sonya Aggarwal,  Boxiang Liu,  Gordon Li,  Scott Soltys,  Melanie Gephart,
# SUCESSFULLY PARSED kakusa2018clinical: " Clinical factors associated with mortality within three mont ... "
#  Juyong Kim,  Milos Pjanic,  Trieu Nguyen,  Clint Miller,  Dharini Iyer,  Boxiang Liu,  Ting Wang,  Olga Sazonova,  Ivan Carcamo-Orive,  Ljubica Matic et al.
# SUCESSFULLY PARSED kim2017tcf21: " TCF21 and the environmental sensor aryl-hydrocarbon receptor ... "
#  Hua Li,  Zhong-Dong Liu,  Liu Boxiang,  Jian-Hui Chen,  You-Ning Sun,  Xiao-Ling Lv,  Ze-Sheng Zhang,  Pin Sun,  Pin Zhang,  Yang-Li Wang,
# SUCESSFULLY PARSED li2009application: " Application of the molecular combing technique to starch gra ... "
#  Xin Li,  Yungil Kim,  Emily Tsang,  Joe Davis,  Farhan Damani,  Colby Chiang,  Gaelen Hess,  Zachary Zappala,  Benjamin Strober,  Alexandra Scott et al.
# SUCESSFULLY PARSED li2017impact: " The impact of rare variation on gene expression across tissu ... "
#  Yingmei Li,  Boxiang Liu,  Ian Connolly,  Bina Kakusa,  Wenying Pan,  Seema Nagpal,  Stephen Montgomery,  Melanie Gephart,
# SUCESSFULLY PARSED li2018recurrently: " Recurrently mutated genes differ between leptomeningeal and  ... "
#  Zhongdong Liu,  Benqian Gong,  Yaqiang He,  Zhenxing Li,  Boxiang Liu,
# WARNING Missing Expected Field 'journal' from entry liu2011new: " A new method for the non-destr ... "
#  ZhongDong Liu,  LiZheng Bi,  Guojin Yan,  Shijie Yang,  Chao Yang,  Liu Boxiang,
# WARNING Missing Expected Field 'journal' from entry liu2012effects: " The Effects of Protein Content ... "
#  Zhongdong Liu,  Benqian Gong,  Liang Zhang,  Hongjie An,  Boxiang Liu,
# WARNING Missing Expected Field 'journal' from entry liu2012influence: " The influence of emulsifiers o ... "
#  Zhongdong Liu,  Boxiang Liu,  Mengxing Li,  Min Wei,  Hua Li,  Peng Liu,  Tuo Wan,
# SUCESSFULLY PARSED liu2013scanning: " Scanning probe acoustic microscopy of extruded starch materi ... "
#  Boxiang Liu,  Thushara Perera,
# SUCESSFULLY PARSED liu2015graphical: " A graphical introduction to special relativity based on a mo ... "
#  Boxiang Liu,  Thomas Quertermous,
# SUCESSFULLY PARSED liu2017approximating: " Approximating the Sum of Independent Non-Identical Binomial  ... "
#  Boxiang Liu,  Milos Pjanic,  Ting Wang,  Trieu Nguyen,  Michael Gloudemans,  Abhiram Rao,  Victor Castano,  Sylvia Nurnberg,  Daniel Rader,  Susannah Elwyn et al.
# SUCESSFULLY PARSED liu2018genetic: " Genetic regulatory mechanisms of smooth muscle cells map to  ... "
#  Boxiang Liu,  Michael Gloudemans,  Abhiram Rao,  Erik Ingelsson,  Stephen Montgomery,
# SUCESSFULLY PARSED liu2019abundant: " Abundant associations with gene expression complicate GWAS f ... "
#  Boxiang Liu,  Melissa Calton,  Nathan Abell,  Gillie Benchorin,  Michael Gloudemans,  Ming Chen,  Jane Hu,  Xin Li,  Brunilda Balliu,  Dean Bok et al.
# SUCESSFULLY PARSED liu2019genetic: " Genetic analyses of human fetal retinal pigment epithelium g ... "
#  Boxiang Liu,  Stephen Montgomery,
# SUCESSFULLY PARSED liu2019identifying: " Identifying causal variants and genes using functional genom ... "
#  Boxiang Liu,  Nadine Hussami,  Avanti Shrikumar,  Tyler Shimko,  Salil Bhate,  Scott Longwell,  Stephen Montgomery,  Anshul Kundaje,
# SUCESSFULLY PARSED liu2019multi: " A multi-modal neural network for learning cis and trans regu ... "
#  Vivek Nanda,  Ting Wang,  Milos Pjanic,  Boxiang Liu,  Trieu Nguyen,  Ljubica Matic,  Ulf Hedin,  Simon Koplev,  Lijiang Ma,  Oscar Franz{\'e}n et al.
# SUCESSFULLY PARSED nanda2018functional: " Functional regulatory mechanism of smooth muscle cell-restri ... "
#  Halit Ongen,  Andrew Brown,  Olivier Delaneau,  Nikolaos Panousis,  Alexandra Nica,  Emmanouil Dermitzakis,  GTEx Consortium et al.
# SUCESSFULLY PARSED ongen2017estimating: " Estimating the causal tissues for complex traits and disease ... "
#  Ashis Saha,  Yungil Kim,  Ariel Gewirtz,  Brian Jo,  Chuan Gao,  Ian McDowell,  Barbara Engelhardt,  Alexis Battle,  Fran{\c{c}}ois Aguet,  Kristin Ardlie et al.
# SUCESSFULLY PARSED saha2017co: " Co-expression networks reveal the tissue-specific regulation ... "
#  Meng Tan,  Qin Li,  Raghuvaran Shanmugam,  Robert Piskol,  Jennefer Kohler,  Amy Young,  Kaiwen Liu,  Rui Zhang,  Gokul Ramaswami,  Kentaro Ariyoshi et al.
# SUCESSFULLY PARSED tan2017dynamic: " Dynamic landscape and regulation of RNA editing in mammals  "
#  Taru Tukiainen,  Alexandra-Chlo{\'e} Villani,  Angela Yen,  Manuel Rivas,  Jamie Marshall,  Rahul Satija,  Matt Aguirre,  Laura Gauthier,  Mark Fleharty,  Andrew Kirby et al.
# SUCESSFULLY PARSED tukiainen2017landscape: " Landscape of X chromosome inactivation across human tissues  "
#  Min Wei,  Yong Liu,  Boxiang Liu,  Xiaoling Lv,  Pin Sun,  Zesheng Zhang,  Fengshou Zhang,  Su Yin,  Zhongdong Liu,
# SUCESSFULLY PARSED wei2011preparation: " Preparation and application of starch phosphate with a low d ... "
#  Min Wei,  Yong Liu,  Changxiao Ju,  Boxiang Liu,  Zhongdong Liu,
# WARNING Missing Expected Field 'journal' from entry wei2012studies: " Studies on the Preparation, St ... "
#  Robert Wirka,  Dhananjay Wagh,  David Paik,  Milos Pjanic,  Trieu Nguyen,  Clint Miller,  Ramen Kundu,  Manabu Nagao,  John Coller,  Tiffany Koyano et al.
# SUCESSFULLY PARSED wirka2019atheroprotective: " Atheroprotective roles of smooth muscle cell phenotypic modu ... "
#  Zhihao Wu,  Yan Wang,  Junghyun Lim,  Boxiang Liu,  Yanping Li,  Rasika Vartak,  Trisha Stankiewicz,  Stephen Montgomery,  Bingwei Lu,
# SUCESSFULLY PARSED wu2018ubiquitination: " Ubiquitination of ABCE1 by NOT4 in response to mitochondrial ... "
#  Fan Yang,  Jiebiao Wang,  Brandon Pierce,  Lin Chen,  Fran{\c{c}}ois Aguet,  Kristin Ardlie,  Beryl Cummings,  Ellen Gelfand,  Gad Getz,  Kane Hadley et al.
# SUCESSFULLY PARSED yang2017identifying: " Identifying cis-mediators for trans-eQTLs across many human  ... "
